# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
import re

# %%
df=pd.read_csv('dataset_extract.csv')

# %%
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r' ',text)

# %%
#To remove [] from title
#Creates additional lists for title length and description length (word count)

titles = []
desc=[]
desc_length=[]
title_length=[]

game_limit = len(df)
for idx , row in df[:game_limit].iterrows():
    t = (row['Title']).replace('[','')
    t = t.replace(']', '')
    d=deEmojify(row['Description'])
    desc.append(d)
    titles.append(t)
    dl=len(row['Description'].split(' '))
    desc_length.append(dl)
    tl=len(row['Title'].split(' '))
    title_length.append(tl)

# %%
#Create new columns from lists in loop
df['Title']=titles
df['Description']=desc
df['Title Words']=title_length
df['Desc Words']=desc_length

# %%
df
# Out:
#      Unnamed: 0                                   Title       Genre  \
# 0             0            capoeira + flow mighty omega    Fighting
# 1             1  2x logia update 3.5 grand piece online   Adventure
# 2             2                                vesteria   Adventure
# 3             3                           2x exp shindo  All Genres
# 4             4  updated peace treaties rise of nations    Military
# ..          ...                                     ...         ...
# 384         384      season 4  anime fighting simulator    Fighting
# 385         385        super luck  bubble gum simulator  All Genres
# 386         386                sled simulator update 2!  All Genres
# 387         387                       lifting simulator    Fighting
# 388         388                   destruction simulator  All Genres
#
#      Favorite count  Maximum Visits  Total Visitors  likes count  \
# 0             30742              35         2788642         7874
# 1            309465               1        53742605       173526
# 2            358269              10        23670840       112076
# 3           1535708               5       834922089       979471
# 4            199107              50        39009742        74469
# ..              ...             ...             ...          ...
# 384         2288946              20       980829466      1045145
# 385         3173194              10      1122493829       919361
# 386           54881              10         5769579        16751
# 387          852514              30       356092656       189171
# 388         2233791               7       367798173       547043
#
#      dislikes count                                        Description  \
# 0               859  Sequel to our previous game on Tokita_Ohma acc...
# 1              9028  PC ONLY\r\nLong awaited naval adventure experi...
# 2             10878  Explore breathtaking worlds, fight powerful mo...
# 3             60486  056 UPDATE:\r\nhttps://www.youtube.com/watch?v...
# 4             11636  Grand Strategy game focused on world dominatio...
# ..              ...                                                ...
# 384           52838  Anime Fighting Simulator is a training game in...
# 385          119677  Super Luck Event!\r\n-   2x Luck\r\n-   2x Myt...
# 386            3304    Latest code: "MollysBowl" - NEW BASE!\r\n  N...
# 387           32792    UPDATE LOG {V 9.5}  \r\n- ⭐️ 6 New Body Alte...
# 388           43549    UPDATE LOG:  \r\n- ❓ Lucky Blocks (Open for ...
#
#     Date Created  ... Age of Game  Visitors Per Day  Likes Per Day  \
# 0       4/9/2020  ...         413      6.752160e+03      19.065375
# 1       5/6/2018  ...        1117      4.811334e+04     155.350045
# 2      9/18/2018  ...         982      2.410473e+04     114.130346
# 3      1/20/2020  ...         493      1.693554e+06    1986.756592
# 4     11/14/2018  ...         925      4.217269e+04      80.507027
# ..           ...  ...         ...               ...            ...
# 384    10/4/2019  ...         601      1.631996e+06    1739.009983
# 385   10/23/2018  ...         947      1.185316e+06     970.814150
# 386    1/21/2021  ...         126      4.579031e+04     132.944444
# 387    8/14/2019  ...         652      5.461544e+05     290.139571
# 388    8/19/2018  ...        1012      3.634369e+05     540.556324
#
#      Dislikes Per Day  Ratings Per Day Favorites Per Day  Title length  \
# 0            2.079903        21.145278         74.435835            30
# 1            8.082363       163.432408        277.050134            40
# 2           11.077393       125.207739        364.836049             8
# 3          122.689655      2109.446247       3115.026369            15
# 4           12.579459        93.086486        215.250811            40
# ..                ...              ...               ...           ...
# 384         87.916805      1826.926789       3808.562396            34
# 385        126.374868      1097.189018       3350.785639            35
# 386         26.222222       159.166667        435.563492            26
# 387         50.294479       340.434049       1307.536810            19
# 388         43.032609       583.588933       2207.303360            23
#
#      Desc length  Title Words  Desc Words
# 0            590            5          78
# 1            481            7          63
# 2            293            1          40
# 3            380            3          24
# 4            593            6          96
# ..           ...          ...         ...
# 384          767            6          89
# 385          785            7         127
# 386          530            4          90
# 387          614            4         107
# 388          654            4         107
#
# [389 rows x 26 columns]

# %%
df=df.drop(['Unnamed: 0', 'Favorite count', 'Maximum Visits', 'Total Visitors', 'likes count', 'dislikes count', 'Description', 'Date Created'], axis=1)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Date Updated', 'GC - Most Engaging',
#        'GC - Up-and-Coming', 'GC - Popular', 'GC - People Love',
#        'Current Date', 'Age of Game', 'Visitors Per Day', 'Likes Per Day',
#        'Dislikes Per Day', 'Ratings Per Day', 'Favorites Per Day',
#        'Title length', 'Desc length', 'Title Words', 'Desc Words'],
#       dtype='object')

# %%
df=df.drop(['Date Updated', 'GC - Up-and-Coming', 'GC - Popular', 'GC - People Love',
       'Current Date', 'Ratings Per Day'], axis=1)

# %%
df
# Out:
#                                       Title       Genre  GC - Most Engaging  \
# 0              capoeira + flow mighty omega    Fighting                   1
# 1    2x logia update 3.5 grand piece online   Adventure                   1
# 2                                  vesteria   Adventure                   1
# 3                             2x exp shindo  All Genres                   1
# 4    updated peace treaties rise of nations    Military                   1
# ..                                      ...         ...                 ...
# 384      season 4  anime fighting simulator    Fighting                   0
# 385        super luck  bubble gum simulator  All Genres                   1
# 386                sled simulator update 2!  All Genres                   0
# 387                       lifting simulator    Fighting                   0
# 388                   destruction simulator  All Genres                   0
#
#      Age of Game  Visitors Per Day  Likes Per Day  Dislikes Per Day  \
# 0            413      6.752160e+03      19.065375          2.079903
# 1           1117      4.811334e+04     155.350045          8.082363
# 2            982      2.410473e+04     114.130346         11.077393
# 3            493      1.693554e+06    1986.756592        122.689655
# 4            925      4.217269e+04      80.507027         12.579459
# ..           ...               ...            ...               ...
# 384          601      1.631996e+06    1739.009983         87.916805
# 385          947      1.185316e+06     970.814150        126.374868
# 386          126      4.579031e+04     132.944444         26.222222
# 387          652      5.461544e+05     290.139571         50.294479
# 388         1012      3.634369e+05     540.556324         43.032609
#
#      Favorites Per Day  Title length  Desc length  Title Words  Desc Words
# 0            74.435835            30          590            5          78
# 1           277.050134            40          481            7          63
# 2           364.836049             8          293            1          40
# 3          3115.026369            15          380            3          24
# 4           215.250811            40          593            6          96
# ..                 ...           ...          ...          ...         ...
# 384        3808.562396            34          767            6          89
# 385        3350.785639            35          785            7         127
# 386         435.563492            26          530            4          90
# 387        1307.536810            19          614            4         107
# 388        2207.303360            23          654            4         107
#
# [389 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
vpd = df["Visitors Per Day"].values.reshape(-1, 1)
vpd_scaler = StandardScaler().fit(vpd)
lpd = df["Likes Per Day"].values.reshape(-1, 1)
lpd_scaler = StandardScaler().fit(lpd)
dpd = df["Dislikes Per Day"].values.reshape(-1, 1)
dpd_scaler = StandardScaler().fit(dpd)
fpd = df["Dislikes Per Day"].values.reshape(-1, 1)
fpd_scaler = StandardScaler().fit(fpd)

# %%
vpd_scaled=vpd_scaler.transform(vpd)
lpd_scaled=lpd_scaler.transform(lpd)
dpd_scaled=dpd_scaler.transform(dpd)
fpd_scaled=fpd_scaler.transform(fpd)

# %%
df['vpd_scaled']=vpd_scaled
df['lpd_scaled']=lpd_scaled
df['dpd_scaled']=dpd_scaled
df['fpd_scaled']=fpd_scaled

# %%
df['Engagement Per Day']=df['vpd_scaled']+df['lpd_scaled']+df['dpd_scaled']+df['fpd_scaled']

# %%
df
# Out:
#                                       Title       Genre  GC - Most Engaging  \
# 0              capoeira + flow mighty omega    Fighting                   1
# 1    2x logia update 3.5 grand piece online   Adventure                   1
# 2                                  vesteria   Adventure                   1
# 3                             2x exp shindo  All Genres                   1
# 4    updated peace treaties rise of nations    Military                   1
# ..                                      ...         ...                 ...
# 384      season 4  anime fighting simulator    Fighting                   0
# 385        super luck  bubble gum simulator  All Genres                   1
# 386                sled simulator update 2!  All Genres                   0
# 387                       lifting simulator    Fighting                   0
# 388                   destruction simulator  All Genres                   0
#
#      Age of Game  Visitors Per Day  Likes Per Day  Dislikes Per Day  \
# 0            413      6.752160e+03      19.065375          2.079903
# 1           1117      4.811334e+04     155.350045          8.082363
# 2            982      2.410473e+04     114.130346         11.077393
# 3            493      1.693554e+06    1986.756592        122.689655
# 4            925      4.217269e+04      80.507027         12.579459
# ..           ...               ...            ...               ...
# 384          601      1.631996e+06    1739.009983         87.916805
# 385          947      1.185316e+06     970.814150        126.374868
# 386          126      4.579031e+04     132.944444         26.222222
# 387          652      5.461544e+05     290.139571         50.294479
# 388         1012      3.634369e+05     540.556324         43.032609
#
#      Favorites Per Day  Title length  Desc length  Title Words  Desc Words  \
# 0            74.435835            30          590            5          78
# 1           277.050134            40          481            7          63
# 2           364.836049             8          293            1          40
# 3          3115.026369            15          380            3          24
# 4           215.250811            40          593            6          96
# ..                 ...           ...          ...          ...         ...
# 384        3808.562396            34          767            6          89
# 385        3350.785639            35          785            7         127
# 386         435.563492            26          530            4          90
# 387        1307.536810            19          614            4         107
# 388        2207.303360            23          654            4         107
#
#      vpd_scaled  lpd_scaled  dpd_scaled  fpd_scaled  Engagement Per Day
# 0     -0.404259   -0.759832   -0.647173   -0.647173           -2.458437
# 1     -0.387965   -0.592760   -0.602989   -0.602989           -2.186702
# 2     -0.397423   -0.643291   -0.580942   -0.580942           -2.202599
# 3      0.260239    1.652373    0.240638    0.240638            2.393887
# 4     -0.390305   -0.684510   -0.569886   -0.569886           -2.214586
# ..          ...         ...         ...         ...                 ...
# 384    0.235989    1.348659   -0.015326   -0.015326            1.553996
# 385    0.060024    0.406923    0.267764    0.267764            1.002476
# 386   -0.388880   -0.620227   -0.469461   -0.469461           -1.948029
# 387   -0.191767   -0.427520   -0.292265   -0.292265           -1.203817
# 388   -0.263747   -0.120533   -0.345719   -0.345719           -1.075718
#
# [389 rows x 17 columns]

# %%
#Establish regression variables
X=df[['Age of Game', 'Engagement Per Day', 'Title Words', 'Desc Words']]
y=df['GC - Most Engaging']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7560137457044673
# Testing Data Score: 0.673469387755102

# %%
new_df=df[['Title','Age of Game', 'Engagement Per Day', 'Title Words', 'Desc Words', 'GC - Most Engaging']]
new_df
# Out:
#                                       Title  Age of Game  Engagement Per Day  \
# 0              capoeira + flow mighty omega          413           -2.458437
# 1    2x logia update 3.5 grand piece online         1117           -2.186702
# 2                                  vesteria          982           -2.202599
# 3                             2x exp shindo          493            2.393887
# 4    updated peace treaties rise of nations          925           -2.214586
# ..                                      ...          ...                 ...
# 384      season 4  anime fighting simulator          601            1.553996
# 385        super luck  bubble gum simulator          947            1.002476
# 386                sled simulator update 2!          126           -1.948029
# 387                       lifting simulator          652           -1.203817
# 388                   destruction simulator         1012           -1.075718
#
#      Title Words  Desc Words  GC - Most Engaging
# 0              5          78                   1
# 1              7          63                   1
# 2              1          40                   1
# 3              3          24                   1
# 4              6          96                   1
# ..           ...         ...                 ...
# 384            6          89                   0
# 385            7         127                   1
# 386            4          90                   0
# 387            4         107                   0
# 388            4         107                   0
#
# [389 rows x 6 columns]

# %%
#Rename columns for database/facilitate app.py
new_df=new_df.rename(columns={"Age of Game":"Age", "Engagement Per Day": "Engagement", "Title Words": "Title_Words", "Desc Words": "Desc_Words", "GC - Most Engaging": "Category"})

# %%
ids=np.arange(389)

new_df['ID']=ids

# %%
#Add an ID Column to be used as the Primary key in the Database
new_df.set_index('ID')
# Out:
#                                       Title   Age  Engagement  Title_Words  \
# ID
# 0              capoeira + flow mighty omega   413   -2.458437            5
# 1    2x logia update 3.5 grand piece online  1117   -2.186702            7
# 2                                  vesteria   982   -2.202599            1
# 3                             2x exp shindo   493    2.393887            3
# 4    updated peace treaties rise of nations   925   -2.214586            6
# ..                                      ...   ...         ...          ...
# 384      season 4  anime fighting simulator   601    1.553996            6
# 385        super luck  bubble gum simulator   947    1.002476            7
# 386                sled simulator update 2!   126   -1.948029            4
# 387                       lifting simulator   652   -1.203817            4
# 388                   destruction simulator  1012   -1.075718            4
#
#      Desc_Words  Category
# ID
# 0            78         1
# 1            63         1
# 2            40         1
# 3            24         1
# 4            96         1
# ..          ...       ...
# 384          89         0
# 385         127         1
# 386          90         0
# 387         107         0
# 388         107         0
#
# [389 rows x 6 columns]

# %%
import json
import psycopg2
from sqlalchemy import create_engine
engine=create_engine('postgres://postgres:Swati@123@localhost:5432/roblox_db')
new_df.to_sql('model_data', con=engine, if_exists='replace', index=False)
