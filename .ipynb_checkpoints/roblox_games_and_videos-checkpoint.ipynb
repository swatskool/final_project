# %% [markdown]
# # Import Dependencies and Create Function

# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from config import g_key
import datetime as dt
import pymongo
import requests
import time
import string
import re

# %%
#function to remove emojis
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r' ',text)

# %% [markdown]
# # Roblox Site Scrape

# %%
#url to be scraped
main_url='https://www.roblox.com/games#/'

most_engaging='https://www.roblox.com/games#/sortName/Curated_96'
popular_url = 'https://www.roblox.com/games#/sortName/Popular'
top_earning='https://www.roblox.com/games#/sortName/TopGrossing'
up_and_coming='https://www.roblox.com/games#/sortName/Curated_60'
top_rated = 'https://www.roblox.com/games#/sortName/TopRated'

#Establish limit of returned results:
game_limit=10

# %%
categories=["Most Engaging", "Up-and-Coming", "Popular", "Top Rated"]
roblox_dict={}

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(main_url)

for c in categories:
  
    time.sleep(10)
    browser.find_by_text(c).click()
    time.sleep(10)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    results = soup.find_all("li", class_=["game-card", 'game-tile'])

    # Loop through returned results
    title_list = []
    users_list=[]
    rating_list=[]
    game_link_list=[]
    game_image_list=[]
    game_id_list=[]
    game_category=[]

    for result in results[0:game_limit]:
        # Error handling
        try:
            # Identify and return title of listing
            title = result.find('div', class_="game-card-name game-name-title").text.lower().strip()
            num_users=result.find('span', class_="info-label playing-counts-label").text
            rating=result.find('span', class_="info-label vote-percentage-label").text
            game_link=result.a['href']
            game_image=result.img['src']
            game_id=result.a['id']

            title_list.append(deEmojify(title))
            users_list.append(num_users)
            rating_list.append(rating)
            game_link_list.append(game_link)
            game_image_list.append(game_image)
            game_id_list.append(game_id)
            game_category.append(c)

        except AttributeError as e:
            print(e)


    roblox_data={
                'Game Category': game_category,
                'Game ID': game_id_list,
                'Title': title_list,
                'User Count': users_list,
                'Positive Ratings': rating_list,
                'Game Link URL': game_link_list,
                'Game Image URL': game_image_list
                }



    roblox_dict[f'{c}']=roblox_data


    browser.back()
    
browser.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\swats\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
roblox_df1=pd.DataFrame(roblox_dict["Most Engaging"])
roblox_df2=pd.DataFrame(roblox_dict["Up-and-Coming"])
roblox_df3=pd.DataFrame(roblox_dict["Popular"])
roblox_df4=pd.DataFrame(roblox_dict["Top Rated"])

# %%
# manipulate %
roblox_df1['Positive Ratings'] = list(map(lambda x: x[:-1], roblox_df1['Positive Ratings'].values))
roblox_df2['Positive Ratings'] = list(map(lambda x: x[:-1], roblox_df2['Positive Ratings'].values))
roblox_df3['Positive Ratings'] = list(map(lambda x: x[:-1], roblox_df3['Positive Ratings'].values))
roblox_df4['Positive Ratings'] = list(map(lambda x: x[:-1], roblox_df4['Positive Ratings'].values))

#manipulate user count #
roblox_df1['User Count'] = (roblox_df1['User Count']).str.replace('K','000')
roblox_df1['User Count']=(roblox_df1['User Count']).str.replace(".","")

roblox_df2['User Count'] = (roblox_df2['User Count']).str.replace('K','000')
roblox_df2['User Count']=(roblox_df2['User Count']).str.replace(".","")

roblox_df3['User Count'] = (roblox_df3['User Count']).str.replace('K','000')
roblox_df3['User Count']=(roblox_df3['User Count']).str.replace(".","")

roblox_df4['User Count'] = (roblox_df4['User Count']).str.replace('K','000')
roblox_df4['User Count']=(roblox_df4['User Count']).str.replace(".","")

#Format numbers
roblox_df1['User Count'] = (roblox_df1['User Count']).astype('float64')
roblox_df1['Positive Ratings'] = (roblox_df1['Positive Ratings']).astype('float64')

roblox_df2['User Count'] = (roblox_df2['User Count']).astype('float64')
roblox_df2['Positive Ratings'] = (roblox_df2['Positive Ratings']).astype('float64')

roblox_df3['User Count'] = (roblox_df3['User Count']).astype('float64')
roblox_df3['Positive Ratings'] = (roblox_df3['Positive Ratings']).astype('float64')

roblox_df4['User Count'] = (roblox_df4['User Count']).astype('float64')
roblox_df4['Positive Ratings'] = (roblox_df4['Positive Ratings']).astype('float64')

#Remove remaining emojis
roblox_df1=roblox_df1.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
roblox_df2=roblox_df2.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
roblox_df3=roblox_df3.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
roblox_df4=roblox_df4.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
roblox_df_all=pd.concat([roblox_df1, roblox_df2, roblox_df3, roblox_df4])

# %%
# manipulate %
roblox_df_all['Positive Ratings'] = list(map(lambda x: x[:-1], roblox_df_all['Positive Ratings'].values))

#manipulate user count #
roblox_df_all['User Count'] = (roblox_df_all['User Count']).str.replace('K','000')
roblox_df_all['User Count']=(roblox_df_all['User Count']).str.replace(".","")

#Format numbers
roblox_df_all['User Count'] = (roblox_df_all['User Count']).astype('float64')
roblox_df_all['Positive Ratings'] = (roblox_df_all['Positive Ratings']).astype('float64')

#Remove remaining emojis
roblox_df_all=roblox_df_all.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

roblox_df_all
# Out:
#    Game Category     Game ID                                            Title  \
# 0  Most Engaging  1663370770                   [capoeira + flow] mighty omega
# 1  Most Engaging   648454481         [2x logia update 3.5] grand piece online
# 2  Most Engaging   105689481                                    miner's haven
# 3  Most Engaging  1511883870                         [update + 2x exp] shindo
# 4  Most Engaging   918677693         [updated peace treaties] rise of nations
# 5  Most Engaging  1278035280                   warrior cats: ultimate edition
# 6  Most Engaging   943733974                 week iv     bitcoin miner [beta]
# 7  Most Engaging   892043755              [ super luck ] bubble gum simulator
# 8  Most Engaging  1348402608               season 4  anime fighting simulator
# 9  Most Engaging  2050890865  [release + huge update] stands awakening [beta]
# 0  Up-and-Coming  1089751448                                 mako mermaids!
# 1  Up-and-Coming  2093229603           [4 characters] friday night funkyn' rp
# 2  Up-and-Coming  2577955438                                [new] animal life
# 3  Up-and-Coming  1704101737                                       toy tycoon
# 4  Up-and-Coming   220828728                                   fashion famous
# 5  Up-and-Coming  2455935718                            food magnet simulator
# 6  Up-and-Coming  2366581908                         super cool parkour obby!
# 7  Up-and-Coming  2517823158                                rainbow fun obby!
# 8  Up-and-Coming  1265527561                                airplane [story]
# 9  Up-and-Coming  1128795217              [dogs!] welcome to farmtown! [beta]
# 0        Popular  1686885941                                   brookhaven  rp
# 1        Popular   994732206                          [update 14] blox fruits
# 2        Popular   383310974                                        adopt me!
# 3        Popular  1511883870                         [update + 2x exp] shindo
# 4        Popular    66654135                                 murder mystery 2
# 5        Popular  1720936166                 [update!] all star tower defense
# 6        Popular   111958650                                          arsenal
# 7        Popular  1016936714                new update your bizarre adventure
# 8        Popular    88070565                              welcome to bloxburg
# 9        Popular  2404080894                              [tabi] funky friday
# 0      Top Rated  2439513265                             dream island  tycoon
# 4  https://t2.rbxcdn.com/f3008dce8b64ac0e22b9e055...
# 5  https://t7.rbxcdn.com/afc0ac1c1df98b7ad8c3ecc7...
# 6  https://t4.rbxcdn.com/1d3eb96c76eeb1e674afb3ab...
# 7  https://t2.rbxcdn.com/de9a80c9158e5c8de04a1888...
# 8  https://t7.rbxcdn.com/d2e9f1d187faf0bc360585ec...
# 9  https://t6.rbxcdn.com/2525bd623e7365ccfa7c2f8c...

# %%
roblox_df_all=roblox_df_all.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
roblox_df_all.dtypes
# Out:
# Game Category       object
# Game ID             object
# Title               object
# User Count          object
# Positive Ratings    object
# Game Link URL       object
# Game Image URL      object
# dtype: object

# %%
roblox_df1.to_csv('games1.csv')
roblox_df2.to_csv('games2.csv')
roblox_df3.to_csv('games3.csv')
roblox_df4.to_csv('games4.csv')
roblox_df_all.to_csv('games.csv')

# %%
sort_df=roblox_df_all.sort_values(by='User Count', ascending=False).drop_duplicates(subset=['Game ID'])

# %%
sort_df
# Out:
#    Game Category     Game ID                                            Title  \
# 1        Popular   994732206                          [update 14] blox fruits
# 7      Top Rated  1247975681                         [streaks] big paintball!
# 3  Up-and-Coming  1704101737                                       toy tycoon
# 6      Top Rated  2383988292                               beeface: be a bee!
# 9      Top Rated    88070565                              welcome to bloxburg
# 4        Popular    66654135                                 murder mystery 2
# 5  Most Engaging  1278035280                   warrior cats: ultimate edition
# 7  Most Engaging   892043755              [ super luck ] bubble gum simulator
# 4      Top Rated  2033913602                                      mall tycoon
# 3  Most Engaging  1511883870                         [update + 2x exp] shindo
# 5        Popular  1720936166                 [update!] all star tower defense
# 6        Popular   111958650                                          arsenal
# 3      Top Rated  2448558164                         [ event!] lifting titans
# 6  Most Engaging   943733974                 week iv     bitcoin miner [beta]
# 9        Popular  2404080894                              [tabi] funky friday
# 0        Popular  1686885941                                   brookhaven  rp
# 1      Top Rated  2492481398                                 noob army tycoon
# 7        Popular  1016936714                new update your bizarre adventure
# 5  Up-and-Coming  2455935718                            food magnet simulator
# 0      Top Rated  2439513265                             dream island  tycoon
# 5      Top Rated  1691616425                                    my hero mania
# 7  Up-and-Coming  2517823158                                rainbow fun obby!
# 6  Up-and-Coming  2366581908                         super cool parkour obby!
# 8  Most Engaging  1348402608               season 4  anime fighting simulator
# 4  Up-and-Coming   220828728                                   fashion famous
# 9  Up-and-Coming  1128795217              [dogs!] welcome to farmtown! [beta]
# 1  Up-and-Coming  2093229603           [4 characters] friday night funkyn' rp
# 4  Most Engaging   918677693         [updated peace treaties] rise of nations
# 0  Up-and-Coming  1089751448                                 mako mermaids!
# 1  Most Engaging   648454481         [2x logia update 3.5] grand piece online
# 0  Most Engaging  1663370770                   [capoeira + flow] mighty omega
# 2  Most Engaging   105689481                                    miner's haven
# 8      Top Rated   601130232                              bee swarm simulator
# 2        Popular   383310974                                        adopt me!
# 9  Most Engaging  2050890865  [release + huge update] stands awakening [beta]
# 2      Top Rated  2253490805                              get a snack at 4 am
# 8  Up-and-Coming  1265527561                                airplane [story]
# 2  Up-and-Coming  2577955438                                [new] animal life
#
#    User Count Positive Ratings  \
# 1   9220000.0             93.0
)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    try:
        
        fav_result = soup.find_all("span", class_=["game-favorite-count"])
        des = soup.find_all('pre', class_=['text game-description linkify'])
        positive_vote_result = soup.find_all('span', class_= ['vote-text'])
        visit_result = soup.find_all("p", class_=["text-lead font-caption-body wait-for-i18n-format-render"])
        fav = (fav_result[0].text)
        fav = int(fav.replace(',', ''))
        #for some weird reason the dates are not getting extracted
        dates_result = soup.find_all('p', class_= 'text-lead font-caption-body')
        # print(dates_result)
    #     What all cleaning is required here ?

        descrip = (des[0].text)


        v = int(visit_result[2]['title'].replace(',',''))
        g = visit_result[4].text
        mv = int(visit_result[3].text)
        l = int(positive_vote_result[0]['title'])
        d = int(positive_vote_result[1]['title'])
    
    except AttributeError as e:
            print(e)
    
    
    
    created.append(dates_result[0].text)
    updated.append(dates_result[1].text)
    description.append(descrip)
    dislikes.append(d)
    likes.append(l)
    favorites.append(fav)
    totalvisits.append(v)
    Genre.append(g)
    maxvisit.append(mv)
game_detail_df = pd.DataFrame({'Title':games_df['Title'][:game_limit], 'Genre': Genre, 'Favorite count': favorites, 'Maximum Visits': maxvisit, 'Total Visitors':totalvisits, 'likes count':likes, 'dislikes count': dislikes, 'Description':description, 'Date Created': created, 'Date Updated': updated})
browser.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\kashe\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
game_detail_df
# Out:
#                                         Title       Genre  Favorite count  \
# 0              [capoeira + flow] mighty omega    Fighting           30742
# 1    [2x logia update 3.5] grand piece online   Adventure          309465
# 2                                    vesteria   Adventure          358269
# 3                             [2x exp] shindo  All Genres         1535708
# 4    [updated peace treaties] rise of nations    Military          199107
# ..                                        ...         ...             ...
# 384        season 4  anime fighting simulator    Fighting         2288946
# 385       [ super luck ] bubble gum simulator  All Genres         3173194
# 386                sled simulator [update 2!]  All Genres           54881
# 387                         lifting simulator    Fighting          852514
# 388                     destruction simulator  All Genres         2233791
#
#      Maximum Visits  Total Visitors  likes count  dislikes count  \
# 0                35         2788642         7874             859
# 1                 1        53742605       173526            9028
# 2                10        23670840       112076           10878
# 3                 5       834922089       979471           60486
# 4                50        39009742        74469           11636
# ..              ...             ...          ...             ...
# 384              20       980829466      1045145           52838
# 385              10      1122493829       919361          119677
# 386              10         5769579        16751            3304
# 387              30       356092656       189171           32792
# 388               7       367798173       547043           43549
#
#                                            Description Date Created  \
# 0    Sequel to our previous game on Tokita_Ohma acc...     4/9/2020
# 1    PC ONLY\nLong awaited naval adventure experien...     5/6/2018
# 2    Explore breathtaking worlds, fight powerful mo...    9/18/2018
# 3    056 UPDATE:\nhttps://www.youtube.com/watch?v=I...    1/20/2020
# 4    Grand Strategy game focused on world dominatio...   11/14/2018
# ..                                                 ...          ...
# 384  Anime Fighting Simulator is a training game in...    10/4/2019
# 385  Super Luck Event!\n- 🍀 2x Luck\n- 💪 2x Mythic\...   10/23/2018
# 386  📣 Latest code: "MollysBowl" - NEW BASE!\n🚨 NEW...    1/21/2021
# 387  📙 UPDATE LOG {V 9.5} 📙\n- ⭐️ 6 New Body Alteri...    8/14/2019
# 388  🚨 UPDATE LOG: 🚨\n- ❓ Lucky Blocks (Open for fr...    8/19/2018
#
#     Date Updated
# 0      5/25/2021
# 1      5/25/2021
# 2      5/25/2021
# 3      5/23/2021
# 4      5/18/2021
# ..           ...
# 384    5/22/2021
# 385     5/8/2021
# 386    5/25/2021
# 387     2/2/2021
# 388    5/21/2021
#
# [389 rows x 10 columns]

# %%
game_detail_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-395ab933dd15> in <module>
# ----> 1 game_detail_df
#
# NameError: name 'game_detail_df' is not defined

# %%
game_detail_df
# Out:
#                                         Title       Genre  Favorite count  \
# 0              [capoeira + flow] mighty omega    Fighting           30025
# 1    [2x logia update 3.5] grand piece online   Adventure          306450
# 2                                    vesteria   Adventure          356118
# 3                             [2x exp] shindo  All Genres         1526506
# 4    [updated peace treaties] rise of nations    Military          198212
# ..                                        ...         ...             ...
# 384        season 4  anime fighting simulator    Fighting         2283997
# 385       [ super luck ] bubble gum simulator  All Genres         3171694
# 386                sled simulator [update 2!]  All Genres           50782
# 387                         lifting simulator    Fighting          851525
# 388                     destruction simulator  All Genres         2231179
#
#      Maximum Visits  Total Visitors  likes count  dislikes count  \
# 0                35         2711700         7745             846
# 1                 1        52657426       171280            8946
# 2                10        23429074       111341           10799
# 3                 5       829036947       964511           60358
# 4                50        38770535        74140           11574
# ..              ...             ...          ...             ...
# 384              20       978819523      1043216           52746
# 385              10      1121868063       918776          119601
# 386              10         5275846        15182            3056
# 387              30       355562255       188890           32740
# 388               7       367269015       546138           43493
#
#                                            Description
# 0    Sequel to our previous game on Tokita_Ohma acc...
# 1    PC ONLY\nLong awaited naval adventure experien...
# 2    Explore breathtaking worlds, fight powerful mo...
# 3    056 UPDATE:\nhttps://www.youtube.com/watch?v=I...
# 4    Grand Strategy game focused on world dominatio...
# ..                                                 ...
# 384  Anime Fighting Simulator is a training game in...
# 385  Super Luck Event!\n- 🍀 2x Luck\n- 💪 2x Mythic\...
# 386  📣 Latest code: "MollysBowl" - NEW BASE!\n🚨 NEW...
# 387  📙 UPDATE LOG {V 9.5} 📙\n- ⭐️ 6 New Body Alteri...
# 388  🚨 UPDATE LOG: 🚨\n- ❓ Lucky Blocks (Open for fr...
#
# [389 rows x 8 columns]

# %%
game_detail_df.to_csv('game_details_dates.csv')

# %% [markdown]
# # YouTube Scrape

# %%
id_name = {}

id_name = sort_df[['Game ID', 'Title']]
titles = []
pub_time = []
thumb_nail = []
vid = []
likes = []
views = []
comments = []
vdf = []
name = []
game_id=[]

for each_game in id_name.iterrows():
    keyword = f'learn roblox {each_game[1][0]}'
    url1 = f"https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q={keyword}&key={g_key}"
    response1 = requests.get(url1)
    data1 = response1.json()
    print(url1)
    for i in range(5):
        try:
            titles.append((data1['items'][i]['snippet']['title']))
        except:
            titles.append('NA')
        try:
            pub_time.append(data1['items'][i]['snippet']['publishTime'].split('T')[0])
        except:
            pub_time.append('00:00:00')
        try:
            thumb_nail.append(data1['items'][i]['snippet']['thumbnails']['default']['url'])
        except:
            thumb_nail.append('NA')
        try:
            video_id = data1['items'][i]['id']['videoId']
            vid.append('https://www.youtube.com/watch?v=' + data1['items'][i]['id']['videoId'])
        except:
            video_id = ''
            vid.append('')
        

        url2 = f"https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id={video_id}&key={g_key}"
        response2 = requests.get(url2)
        data2 = response2.json()
        #print(url2)
        try:
            likes.append(int(data2['items'][0]['statistics']['likeCount']))
        except:
            likes.append(0)
        try:
            views.append(int(data2['items'][0]['statistics']['viewCount']))
        except:
            views.append(0)
        try:
            comments.append(int(data2['items'][0]['statistics']['commentCount']))
        except:
            comments.append(0)
        name.append(each_game[1][1])
        game_id.append(each_game[1][0])
# Out:
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 994732206&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1247975681&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1704101737&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2383988292&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 88070565&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 66654135&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1278035280&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 892043755&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2033913602&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1511883870&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1720936166&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 111958650&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2448558164&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 943733974&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2404080894&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1686885941&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2492481398&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1016936714&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2455935718&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2439513265&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1691616425&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2517823158&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2366581908&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1348402608&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 220828728&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1128795217&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2093229603&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 918677693&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1089751448&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 648454481&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1663370770&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 105689481&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 601130232&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 383310974&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2050890865&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2253490805&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 1265527561&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA
# https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=learn roblox 2577955438&key=AIzaSyDu_AIXw6jrdvM94lZLkSsuqSwfpuh0SZA

# %%
video_df = pd.DataFrame({'Game ID': game_id, 'Game Name' : name,  'Videos': titles,  'Views':views, 'Likes': likes,'Comments': comments,'Video Thumbnails': thumb_nail, 'Video url': vid, 'Published on ': pub_time })
video_df.sort_values(by='Views', ascending=False, inplace = True)

# %%
video_df
# Out:
#         Game ID                                        Game Name  \
# 31   1278035280                   warrior cats: ultimate edition
# 107  2517823158                                rainbow fun obby!
# 27     66654135                                 murder mystery 2
# 140  1089751448                                 mako mermaids!
# 137   918677693         [updated peace treaties] rise of nations
# ..          ...                                              ...
# 171  2050890865  [release + huge update] stands awakening [beta]
# 169   383310974                                        adopt me!
# 149   648454481         [2x logia update 3.5] grand piece online
# 98   2439513265                             dream island  tycoon
# 63   2448558164                         [ event!] lifting titans
#
#                                                 Videos    Views  Likes  \
# 31   Roblox How To Code - How To Script On Roblox -...  1069890  26749
# 107  Roblox How To Code - How To Script On Roblox -...  1069890  26749
# 27   Roblox How To Code - How To Script On Roblox -...  1069890  26749
# 140  Roblox How To Code - How To Script On Roblox -...  1069890  26749
# 137  Roblox How To Code - How To Script On Roblox -...  1069890  26749
# ..                                                 ...      ...    ...
# 171              How to Learn to Script on Roblox 2021    11893    557
# 169              How to Learn to Script on Roblox 2021    11893    557
# 149              How to Learn to Script on Roblox 2021    11893    557
# 98               How to Learn to Script on Roblox 2021    11893    557
# 63               How to Learn to Script on Roblox 2021    11893    557
#
#      Comments                                Video Thumbnails  \
# 31       5729  https://i.ytimg.com/vi/BfLUt3mfJiY/default.jpg
# 107      5729  https://i.ytimg.com/vi/BfLUt3mfJiY/default.jpg
# 27       5729  https://i.ytimg.com/vi/BfLUt3mfJiY/default.jpg
# 140      5729  https://i.ytimg.com/vi/BfLUt3mfJiY/default.jpg
# 137      5729  https://i.ytimg.com/vi/BfLUt3mfJiY/default.jpg
# ..        ...                                             ...
# 171       142  https://i.ytimg.com/vi/JXH5-uuCVEk/default.jpg
# 169       142  https://i.ytimg.com/vi/JXH5-uuCVEk/default.jpg
# 18  https://www.youtube.com/watch?v=jngKJLcTSZ4    2020-02-11
# 19  https://www.youtube.com/watch?v=fivk8yp-VT4    2021-01-23
# 16  https://www.youtube.com/watch?v=uPrE4lpTFCU    2019-12-29
# 15  https://www.youtube.com/watch?v=0Grwaj4PyC4    2020-10-04
# ..                                          ...           ...
# 23  https://www.youtube.com/watch?v=BfLUt3mfJiY    2019-07-21
# 20  https://www.youtube.com/watch?v=jngKJLcTSZ4    2020-02-11
# 24  https://www.youtube.com/watch?v=fivk8yp-VT4    2021-01-23
# 22  https://www.youtube.com/watch?v=uPrE4lpTFCU    2019-12-29
# 21  https://www.youtube.com/watch?v=0Grwaj4PyC4    2020-10-04
#
# [190 rows x 9 columns]

# %%
video_df.columns=['game_id','game_title', 'video_name', 'yt_views', 'yt_likes', 'yt_comments', 'yt_thumbnail', 'video_url', 'pub_date']

# %%
video_df.to_csv('roblox_videos.csv')

# %%
roblox_df1.columns=['game_category','game_id','game_title', 'user_count', 'positive_ratings', 'game_url', 'game_image_url']
roblox_df2.columns=['game_category','game_id','game_title', 'user_count', 'positive_ratings', 'game_url', 'game_image_url']
roblox_df3.columns=['game_category','game_id','game_title', 'user_count', 'positive_ratings', 'game_url', 'game_image_url']
roblox_df4.columns=['game_category','game_id','game_title', 'user_count', 'positive_ratings', 'game_url', 'game_image_url']
roblox_df_all.columns=['game_category','game_id','game_title', 'user_count', 'positive_ratings', 'game_url', 'game_image_url']

roblox_df1.to_csv('games1.csv')
roblox_df2.to_csv('games2.csv')
roblox_df3.to_csv('games3.csv')
roblox_df4.to_csv('games4.csv')
roblox_df_all.to_csv('games.csv')

# %%
from sqlalchemy import create_engine
engine=create_engine('postgres://postgres:postgres@localhost:5432/roblox_db')
video_df.to_sql('videos', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-39-9a9d8ff61c5b> in <module>
#       1 from sqlalchemy import create_engine
#       2 engine=create_engine('postgres://postgres:postgres@localhost:5432/roblox_db')
# ----> 3 video_df.to_sql('videos', con=engine, if_exists='replace', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     719
#     720     def create(self):
# --> 721         if self.exists():
#     722             if self.if_exists == "fail":
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     706
#     707     def exists(self):
# --> 708         return self.pd_sql.has_table(self.name, self.schema)
#     709
#     710     def sql_schema(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1428
#    1429     def has_table(self, name, schema=None):
# -> 1430         return self.connectable.run_callable(
#    1431             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1432         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
roblox_df1.to_sql('games1', con=engine, if_exists='replace', index=False)
roblox_df2.to_sql('games2', con=engine, if_exists='replace', index=False)
roblox_df3.to_sql('games3', con=engine, if_exists='replace', index=False)
roblox_df4.to_sql('games4', con=engine, if_exists='replace', index=False)
roblox_df_all.to_sql('games', con=engine, if_exists='replace', index=False)

# %%
import json
import psycopg2

def db(database_name='roblox_db'):
    return psycopg2.connect(database=database_name, user='postgres', password='postgres', host='localhost')

def query_db(query, args=(), one=False):
    cur = db().cursor()
    cur.execute(query, args)
    r = [dict((cur.description[i][0], value) \
               for i, value in enumerate(row)) for row in cur.fetchall()]
    cur.connection.close()
    return (r[0] if r else None) if one else r

videos_query = query_db("select * from videos", (3,))
games_query = query_db("select * from games", (3,))

json_videos = json.dumps(videos_query)
json_games = json.dumps(games_query)

# %%
json_videos

# %%
json_games

# %%
with open('video_data.txt', 'w') as outfile:
    json.dump(videos_query, outfile)

# %%
with open('games_data.txt', 'w') as outfile:
    json.dump(games_query, outfile)
