# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
dataset = pd.read_csv('game_details_compiled.csv')
dataset=dataset.iloc[:, 1:]
dataset.head()
# Out:
#                                       Title       Genre  Favorite count  \
# 0            [capoeira + flow] mighty omega    Fighting           30742
# 1  [2x logia update 3.5] grand piece online   Adventure          309465
# 2                                  vesteria   Adventure          358269
# 3                           [2x exp] shindo  All Genres         1535708
# 4  [updated peace treaties] rise of nations    Military          199107
#
#    Maximum Visits  Total Visitors  likes count  dislikes count  \
# 0              35         2788642         7874             859
# 1               1        53742605       173526            9028
# 2              10        23670840       112076           10878
# 3               5       834922089       979471           60486
# 4              50        39009742        74469           11636
#
#                                          Description Date Created  \
# 0  Sequel to our previous game on Tokita_Ohma acc...     4/9/2020
# 1  PC ONLY\nLong awaited naval adventure experien...     5/6/2018
# 2  Explore breathtaking worlds, fight powerful mo...    9/18/2018
# 3  056 UPDATE:\nhttps://www.youtube.com/watch?v=I...    1/20/2020
# 4  Grand Strategy game focused on world dominatio...   11/14/2018
#
#   Date Updated  GC - Most Engaging  GC - Up-and-Coming  GC - Popular  \
# 0    5/25/2021                   1                   0             0
# 1    5/25/2021                   1                   0             1
# 2    5/25/2021                   1                   0             0
# 3    5/23/2021                   1                   0             1
# 4    5/18/2021                   1                   1             0
#
#    GC - People Love
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0

# %%
dataset.groupby('Genre').mean()
# Out:
#                Favorite count  Maximum Visits  Total Visitors   likes count  \
# Genre
# Adventure        1.476580e+06       19.176471    8.736395e+08  4.064057e+05
# All Genres       8.925209e+05       20.703704    3.385019e+08  2.875525e+05
# Building         1.341638e+06        8.923077    2.533483e+08  3.608162e+05
# Comedy           1.303511e+06       22.500000    5.722531e+08  3.144478e+05
# FPS              4.223287e+06       20.500000    1.318578e+09  1.558930e+06
# Fighting         9.663401e+05       18.707692    3.434754e+08  2.956888e+05
# Horror           7.141253e+06       10.714286    4.245314e+09  2.075253e+06
# Military         2.944962e+05       21.000000    4.018782e+07  1.051315e+05
# Naval            5.899820e+05       60.000000    1.522790e+08  1.416405e+05
# RPG              3.048493e+06       38.038462    2.810445e+09  6.778952e+05
# Sci-Fi           1.743910e+06       28.750000    3.122259e+08  4.891492e+05
# Town and City    4.440333e+06       33.653846    2.060359e+09  1.094267e+06
# Western          7.573330e+05       28.000000    8.922875e+07  2.589580e+05
#
#                dislikes count  GC - Most Engaging  GC - Up-and-Coming  \
# Genre
# Adventure        62090.676471            0.156863            0.107843
# All Genres       34227.481481            0.481481            0.160494
# Building         42841.153846            0.461538            0.153846
# Comedy           50740.000000            0.000000            0.333333
# FPS             197868.000000            0.000000            0.000000
# Fighting         40053.200000            0.153846            0.138462
# Horror          187435.857143            0.142857            0.000000
# Military         10538.000000            0.187500            1.000000
# Naval            17249.000000            0.000000            1.000000
# RPG             110028.192308            0.461538            0.153846
# Sci-Fi           59653.000000            0.000000            0.500000
# Town and City   140413.269231            0.153846            0.096154
# Western          41161.666667            0.666667            0.333333
#
#                GC - Popular  GC - People Love
# Genre
# Adventure          0.235294          0.264706
# All Genres         0.395062          0.296296
# Building           0.000000          0.000000
# Comedy             0.333333          0.333333
# FPS                0.916667          0.750000
# Fighting           0.138462          0.169231
# Horror             0.857143          0.571429
# Military           0.625000          0.625000
# Naval              0.000000          0.000000
# RPG                0.653846          0.384615
# Sci-Fi             0.000000          0.000000
# Town and City      0.403846          0.403846
# Western            0.666667          0.000000

# %%
dataset.groupby('GC - Most Engaging').mean()
# Out:
#                     Favorite count  Maximum Visits  Total Visitors  \
# GC - Most Engaging
# 0                     2.036299e+06       23.513699    1.097345e+09
# 1                     1.467487e+06       20.092784    5.502327e+08
#
#                       likes count  dislikes count  GC - Up-and-Coming  \
# GC - Most Engaging
# 0                   534539.150685    76827.373288            0.178082
# 1                   483677.412371    46915.546392            0.154639
#
#                     GC - Popular  GC - People Love
# GC - Most Engaging
# 0                       0.260274          0.260274
# 1                       0.597938          0.432990

# %%
dataset['GC - Most Engaging'].value_counts()
# Out:
# 0    292
# 1     97
# Name: GC - Most Engaging, dtype: int64

# %%
table=pd.crosstab(dataset.Genre,dataset['GC - Most Engaging'])

# %%
table
# Out:
# GC - Most Engaging   0   1
# Genre
# Adventure           86  16
# All Genres          42  39
# Building             7   6
# Comedy               6   0
# FPS                 12   0
# Fighting            55  10
# Horror               6   1
# Military            13   3
# Naval                2   0
# RPG                 14  12
# Sci-Fi               4   0
# Town and City       44   8
# Western              1   2

# %%
import datetime as dt

today = dt.date.today()
dataset['Current Date']=today
current_date=pd.to_datetime(dataset['Current Date'])

date_created = pd.to_datetime(dataset['Date Created'], format='%m/%d/%Y')
age_of_game=(current_date-date_created).dt.days

dataset['Age of Game']=age_of_game
dataset['Visitors Per Day']=dataset['Total Visitors']/dataset['Age of Game']
dataset['Likes Per Day']=dataset['likes count']/dataset['Age of Game']
dataset['Dislikes Per Day']=dataset['dislikes count']/dataset['Age of Game']
dataset['Ratings Per Day']=dataset['Likes Per Day']+dataset['Dislikes Per Day']
dataset['Favorites Per Day']=dataset['Favorite count']/dataset['Age of Game']
dataset['Title length'] =dataset['Title'].str.len()
dataset['Desc length'] =dataset['Description'].str.len()

# %%
dataset
# Out:
#                                         Title       Genre  Favorite count  \
# 0              [capoeira + flow] mighty omega    Fighting           30742
# 1    [2x logia update 3.5] grand piece online   Adventure          309465
# 2                                    vesteria   Adventure          358269
# 3                             [2x exp] shindo  All Genres         1535708
# 4    [updated peace treaties] rise of nations    Military          199107
# ..                                        ...         ...             ...
# 384        season 4  anime fighting simulator    Fighting         2288946
# 385       [ super luck ] bubble gum simulator  All Genres         3173194
# 386                sled simulator [update 2!]  All Genres           54881
# 387                         lifting simulator    Fighting          852514
# 388                     destruction simulator  All Genres         2233791
#
#      Maximum Visits  Total Visitors  likes count  dislikes count  \
# 0                35         2788642         7874             859
# 1                 1        53742605       173526            9028
# 2                10        23670840       112076           10878
# 3                 5       834922089       979471           60486
# 4                50        39009742        74469           11636
# ..              ...             ...          ...             ...
# 384              20       980829466      1045145           52838
# 385              10      1122493829       919361          119677
# 386              10         5769579        16751            3304
# 387              30       356092656       189171           32792
# 388               7       367798173       547043           43549
#
#                                            Description Date Created  \
# 0    Sequel to our previous game on Tokita_Ohma acc...     4/9/2020
# 1    PC ONLY\nLong awaited naval adventure experien...     5/6/2018
# 2    Explore breathtaking worlds, fight powerful mo...    9/18/2018
# 3    056 UPDATE:\nhttps://www.youtube.com/watch?v=I...    1/20/2020
# 4    Grand Strategy game focused on world dominatio...   11/14/2018
# ..                                                 ...          ...
# 384  Anime Fighting Simulator is a training game in...    10/4/2019
# 385  Super Luck Event!\n- 🍀 2x Luck\n- 💪 2x Mythic\...   10/23/2018
# 386  📣 Latest code: "MollysBowl" - NEW BASE!\n🚨 NEW...    1/21/2021
# 387  📙 UPDATE LOG {V 9.5} 📙\n- ⭐️ 6 New Body Alteri...    8/14/2019
# 388  🚨 UPDATE LOG: 🚨\n- ❓ Lucky Blocks (Open for fr...    8/19/2018
#
#     Date Updated  ...  GC - People Love  Current Date  Age of Game  \
# 0      5/25/2021  ...                 0    2021-05-27          413
# 1      5/25/2021  ...                 1    2021-05-27         1117
# 2      5/25/2021  ...                 0    2021-05-27          982
# 3      5/23/2021  ...                 1    2021-05-27          493
# 4      5/18/2021  ...                 0    2021-05-27          925
# ..           ...  ...               ...           ...          ...
# 384    5/22/2021  ...                 0    2021-05-27          601
# 385     5/8/2021  ...                 1    2021-05-27          947
# 386    5/25/2021  ...                 0    2021-05-27          126
# 387     2/2/2021  ...                 0    2021-05-27          652
# 388    5/21/2021  ...                 0    2021-05-27         1012
#
#      Visitors Per Day Likes Per Day  Dislikes Per Day  Ratings Per Day  \
# 0        6.752160e+03     19.065375          2.079903        21.145278
# 1        4.811334e+04    155.350045          8.082363       163.432408
# 2        2.410473e+04    114.130346         11.077393       125.207739
# 3        1.693554e+06   1986.756592        122.689655      2109.446247
# 4        4.217269e+04     80.507027         12.579459        93.086486
# ..                ...           ...               ...              ...
# 384      1.631996e+06   1739.009983         87.916805      1826.926789
# 385      1.185316e+06    970.814150        126.374868      1097.189018
# 386      4.579031e+04    132.944444         26.222222       159.166667
# 387      5.461544e+05    290.139571         50.294479       340.434049
# 388      3.634369e+05    540.556324         43.032609       583.588933
#
#      Favorites Per Day  Title length  Desc length
# 0            74.435835            30          590
# 1           277.050134            40          481
# 2           364.836049             8          293
# 3          3115.026369            15          380
# 4           215.250811            40          593
# ..                 ...           ...          ...
# 384        3808.562396            34          767
# 385        3350.785639            35          785
# 386         435.563492            26          530
# 387        1307.536810            19          614
# 388        2207.303360            23          654
#
# [389 rows x 23 columns]

# %%
dataset.to_csv('dataset_extract.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-20-26523df34baa> in <module>
# ----> 1 dataset.to_csv('dataset_extract.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'dataset_extract.csv'
